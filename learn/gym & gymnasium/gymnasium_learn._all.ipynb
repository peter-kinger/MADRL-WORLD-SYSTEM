# %% [markdown]
# 大部分的 gym 代码 gymnasium 是可以复用的，里面是可以兼容的

# %% [markdown]
# ## 自定义环境-gymnasium

# %% [markdown]
# https://blog.csdn.net/Ever_____/article/details/139503558

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 实例化自定义环境

# %% [markdown]
# https://blog.csdn.net/qq_36592770/article/details/133325814
